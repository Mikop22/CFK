# %% [markdown]
# <a href="https://colab.research.google.com/github/Mikop22/CFK/blob/main/Freshii.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
INSERT INTO menus (
    id,
    name,
    price,
    description,
    ingredients,
    nutritionalFacts,
    thumbnailUrl,
    videoUrl,
    likeCount,
    estimatedMinute,
    discount,
    subSection_id,
    restaurant_id
)
VALUES (
    uuid(),
    "Greek Salad",
    '{ "value": 1199, "currency": "CAD" }',
    "A classic mix of greens, feta, olives, and vinaigrette.",
    '["Romaine", "Field Greens", "Tomatoes", "Cucumbers", "Red Onions", "Olives", "Crumbled feta", "Greek Vinaigrette"]',
    '[{"name": "Calories", "amount": {"unit": "kcal", "value": 275}}, {"name": "Fat", "amount": {"unit": "g", "value": 0}}, {"name": "Fiber", "amount": {"unit": "g", "value": 0}}, {"name": "Protein", "amount": {"unit": "g", "value": 0}}, {"name": "Carbs", "amount": {"unit": "g", "value": 0}}]',
    "https://d1inbgoespaevw.cloudfront.net/menus/thumbnails/greek-salad.png",
    "https://d1inbgoespaevw.cloudfront.net/menus/videos/greek-salad.m3u8",
    0,
    15,
    null,
    null,
    null
);

# %%
INSERT INTO menus (
	id,
	name,
    price,
    description,
    ingredients,
    nutritionalFacts,
    thumbnailUrl,
    videoUrl,
    likeCount,
    estimatedMinute,
    discount,
    subSection_id,
    restaurant_id
)
VALUES (
	uuid(),
    "Mezze Deliight Bowl",
    '{ "value": 1299, "currency": "CAD" }',
    "Fresh veggies, crispy chickpeas, and quinoa with zesty za’atar vinaigrette.",
    '["Quinoa", "Field Greens", "Tomatoes", "Cucumbers", "Cabbage", "Crispy Chickpeas", "Sesame Seeds", "Cilantro", "Lemon Zaatar Vinaigrette", "Tahini Sauce"]',
    '[{"name": "Calories", "amount": {"unit": "kcal", "value": 590}}, {"name": "Fat", "amount": {"unit": "g", "value": 0}}, {"name": "Fiber", "amount": {"unit": "g", "value": 0}}, {"name": "Protein", "amount": {"unit": "g", "value": 0}}, {"name": "Carbs", "amount": {"unit": "g", "value": 0}}]',
    "https://d1inbgoespaevw.cloudfront.net/menus/thumbnails/mezze-deliight-bowl.png",
    "https://d1inbgoespaevw.cloudfront.net/menus/videos/mezze-deliight-bowl.m3u8",
    0,
    15,
    null,
    null,
    null
);

# %%
INSERT INTO menus (
	id,
	name,
    price,
    description,
    ingredients,
    nutritionalFacts,
    thumbnailUrl,
    videoUrl,
    likeCount,
    estimatedMinute,
    discount,
    subSection_id,
    restaurant_id
)
VALUES (
	uuid(),
    "Spiicy Buffalo Bowl",
    '{ "value": 1199, "currency": "CAD" }',
    "A fiery mix of rice, veggies, and buffalo flair.",
    '["Brown Rice", "Romaine", "Tomatoes", "Aged Cheddar", "Jalapenos", "Carrots", "Hot Sauce", "Greek Yogurt Ranch"]',
    '[{"name": "Calories", "amount": {"unit": "kcal", "value": 510}}, {"name": "Fat", "amount": {"unit": "g", "value": 0}}, {"name": "Fiber", "amount": {"unit": "g", "value": 0}}, {"name": "Protein", "amount": {"unit": "g", "value": 0}}, {"name": "Carbs", "amount": {"unit": "g", "value": 0}}]',
    "https://d1inbgoespaevw.cloudfront.net/menus/thumbnails/spiicy-buffalo-bowl.png",
    "https://d1inbgoespaevw.cloudfront.net/menus/videos/spiicy-buffalo-bowl.m3u8",
    0,
    15,
    null,
    null,
    null
);

# %%
INSERT INTO menus (
	id,
	name,
    price,
    description,
    ingredients,
    nutritionalFacts,
    thumbnailUrl,
    videoUrl,
    likeCount,
    estimatedMinute,
    discount,
    subSection_id,
    restaurant_id
)
VALUES (
	uuid(),
    "Teriyaki Twiist Bowl",
    '{ "value": 1099, "currency": "CAD" }',
    "Fresh veggies, crispy chickpeas, and quinoa with zesty za’atar vinaigrette.",
    '["Brown Rice", "Edamame", "Broccoli", "Carrots", "Cucumbers", "Green Onions", "Crispy Wontons", "Sesame Seeds", "Teriyaki Sauce"]',
    '[{"name": "Calories", "amount": {"unit": "kcal", "value": 510}}, {"name": "Fat", "amount": {"unit": "g", "value": 0}}, {"name": "Fiber", "amount": {"unit": "g", "value": 0}}, {"name": "Protein", "amount": {"unit": "g", "value": 0}}, {"name": "Carbs", "amount": {"unit": "g", "value": 0}}]',
    "https://d1inbgoespaevw.cloudfront.net/menus/thumbnails/teriyaki-twiist.png",
    "https://d1inbgoespaevw.cloudfront.net/menus/videos/teriyaki-twiist-bowl.m3u8",
    0,
    15,
    null,
    null,
    null
);

# %%
INSERT INTO menus (
	id,
	name,
    price,
    description,
    ingredients,
    nutritionalFacts,
    thumbnailUrl,
    videoUrl,
    likeCount,
    estimatedMinute,
    discount,
    subSection_id,
    restaurant_id
)
VALUES (
	uuid(),
    "Buddha Satay Burrito",
    '{ "value": 1049, "currency": "CAD" }',
    "Whole wheat wrap loaded with veggies, rice, and bold satay sauce.",
    '["Whole Wheat Tortilla", "Brown Rice", "Broccoli", "Carrots", "Cabbage", "Green Onions", "Crispy Wontons", "Spicy Peanut Sauce"]',
    '[{"name": "Calories", "amount": {"unit": "kcal", "value": 475}}, {"name": "Fat", "amount": {"unit": "g", "value": 0}}, {"name": "Fiber", "amount": {"unit": "g", "value": 0}}, {"name": "Protein", "amount": {"unit": "g", "value": 0}}, {"name": "Carbs", "amount": {"unit": "g", "value": 0}}]',
    "https://d1inbgoespaevw.cloudfront.net/menus/thumbnails/buddha-satay-burrito.png",
    null,
    0,
    15,
    null,
    null,
    null
);

# %%
INSERT INTO menus (
	id,
	name,
    price,
    description,
    ingredients,
    nutritionalFacts,
    thumbnailUrl,
    videoUrl,
    likeCount,
    estimatedMinute,
    discount,
    subSection_id,
    restaurant_id
)
VALUES (
	uuid(),
    "Chiipotle Cheddar Burrito",
    '{ "value": 949, "currency": "CAD" }',
    "A zesty chipotle wrap loaded with rice, beans, and cheddar.",
    '["Whole Wheat Tortilla", "Brown Rice", "Aged Cheddar", "Black Beans", "Tomatoes", "Corn", "Cabbage", "Carrots", "Green Onions", "Creamy Chipotle Dressing"]',
    '[{"name": "Calories", "amount": {"unit": "kcal", "value": 580}}, {"name": "Fat", "amount": {"unit": "g", "value": 0}}, {"name": "Fiber", "amount": {"unit": "g", "value": 0}}, {"name": "Protein", "amount": {"unit": "g", "value": 0}}, {"name": "Carbs", "amount": {"unit": "g", "value": 0}}]',
    "https://d1inbgoespaevw.cloudfront.net/menus/thumbnails/chiipotle-cheddar-burrito.png",
    null,
    0,
    15,
    null,
    null,
    null
);

# %%
INSERT INTO menus (
	id,
	name,
    price,
    description,
    ingredients,
    nutritionalFacts,
    thumbnailUrl,
    videoUrl,
    likeCount,
    estimatedMinute,
    discount,
    subSection_id,
    restaurant_id
)
VALUES (
	uuid(),
    "Mezze Deliight Burrito",
    '{ "value": 1149, "currency": "CAD" }',
    "Wholesome mezze flavours wrapped in a soft whole wheat tortilla.",
    '["Whole Wheat Tortilla", "Quinoa", "Field Greens", "Beets Slaw", "Tomatoes", "Cucumbers", "Cabbage", "Crispy Chickpeas", "Sesame Seeds", "Lemon Zaatar Vinaigrette", "Tahini Sauce"]',
    '[{"name": "Calories", "amount": {"unit": "kcal", "value": 590}}, {"name": "Fat", "amount": {"unit": "g", "value": 0}}, {"name": "Fiber", "amount": {"unit": "g", "value": 0}}, {"name": "Protein", "amount": {"unit": "g", "value": 0}}, {"name": "Carbs", "amount": {"unit": "g", "value": 0}}]',
    "https://d1inbgoespaevw.cloudfront.net/menus/thumbnails/mezze-deliight-burrito.png",
    null,
    0,
    15,
    null,
    null,
    null
);

# %%
INSERT INTO menus (
	id,
	name,
    price,
    description,
    ingredients,
    nutritionalFacts,
    thumbnailUrl,
    videoUrl,
    likeCount,
    estimatedMinute,
    discount,
    subSection_id,
    restaurant_id
)
VALUES (
	uuid(),
    "Oaxaca Burrito",
    '{ "value": 1149, "currency": "CAD" }',
    "A bold blend of beans, avo, and spice wrapped with crispy crunch.",
    '["Whole Wheat Tortilla", "Brown Rice", "Kale", "Avocado", "Beet Slaw, "Black Beans", "Corn", "Salsa Fresca", "Crispy Wontons", "Spicy Yogurt Sauce"]',
    '[{"name": "Calories", "amount": {"unit": "kcal", "value": 695}}, {"name": "Fat", "amount": {"unit": "g", "value": 0}}, {"name": "Fiber", "amount": {"unit": "g", "value": 0}}, {"name": "Protein", "amount": {"unit": "g", "value": 0}}, {"name": "Carbs", "amount": {"unit": "g", "value": 0}}]',
    "https://d1inbgoespaevw.cloudfront.net/menus/thumbnails/oaxaca-burrito.png",
    null,
    0,
    15,
    null,
    null,
    null
);

# %%
INSERT INTO menus (
	id,
	name,
    price,
    description,
    ingredients,
    nutritionalFacts,
    thumbnailUrl,
    videoUrl,
    likeCount,
    estimatedMinute,
    discount,
    subSection_id,
    restaurant_id
)
VALUES (
	uuid(),
    "Spiicy Buffalo Burrito",
    '{ "value": 1049, "currency": "CAD" }',
    "Cheddar, heat, and crunchy. A fiery wrap with a cool finish.",
    '["Whole Wheat Tortilla", "Brown Rice", "Romaine", "Aged Cheddar", "Jalapenos, "Tomatoes", "Carrots", "Hot Sauce", "Greek Yogurt Ranch"]',
    '[{"name": "Calories", "amount": {"unit": "kcal", "value": 510}}, {"name": "Fat", "amount": {"unit": "g", "value": 0}}, {"name": "Fiber", "amount": {"unit": "g", "value": 0}}, {"name": "Protein", "amount": {"unit": "g", "value": 0}}, {"name": "Carbs", "amount": {"unit": "g", "value": 0}}]',
    "https://d1inbgoespaevw.cloudfront.net/menus/thumbnails/spiicy-buffalo-burrito.png",
    null,
    0,
    15,
    null,
    null,
    null
);

# %%
INSERT INTO menus (
	id,
	name,
    price,
    description,
    ingredients,
    nutritionalFacts,
    thumbnailUrl,
    videoUrl,
    likeCount,
    estimatedMinute,
    discount,
    subSection_id,
    restaurant_id
)
VALUES (
	uuid(),
    "Tex Mex Burrito",
    '{ "value": 1149, "currency": "CAD" }',
    "Tex-Mex flavours with black beans, cheddar, and creamy ranch.",
    '["Whole Wheat Tortilla", "Rice", "Hot Black Bean", "Salsa Fresca", "Corn", "Avocado", "Aged Cheddar", "Greek Yogurt Ranch"]',
    '[{"name": "Calories", "amount": {"unit": "kcal", "value": 645}}, {"name": "Fat", "amount": {"unit": "g", "value": 0}}, {"name": "Fiber", "amount": {"unit": "g", "value": 0}}, {"name": "Protein", "amount": {"unit": "g", "value": 0}}, {"name": "Carbs", "amount": {"unit": "g", "value": 0}}]',
    "https://d1inbgoespaevw.cloudfront.net/menus/thumbnails/tex-mex-burrito.png",
    null,
    0,
    15,
    null,
    null,
    null
);

# %%
INSERT INTO menus (
	id,
	name,
    price,
    description,
    ingredients,
    nutritionalFacts,
    thumbnailUrl,
    videoUrl,
    likeCount,
    estimatedMinute,
    discount,
    subSection_id,
    restaurant_id
)
VALUES (
	uuid(),
    "Teriyaki Twiist Burrito",
    '{ "value": 949, "currency": "CAD" }',
    "Fresh crunch meets sweet teriyaki in this flavour-packed burrito.",
    '["Whole Wheat Tortilla", "Brown Rice", "Edamame", "Broccoli", "Carrots", "Cucumbers", "Green Onions", "Crispy Wontons", "Sesame Seeds", "Teriyaki Sauce"]',
    '[{"name": "Calories", "amount": {"unit": "kcal", "value": 480}}, {"name": "Fat", "amount": {"unit": "g", "value": 0}}, {"name": "Fiber", "amount": {"unit": "g", "value": 0}}, {"name": "Protein", "amount": {"unit": "g", "value": 0}}, {"name": "Carbs", "amount": {"unit": "g", "value": 0}}]',
    "https://d1inbgoespaevw.cloudfront.net/menus/thumbnails/teriyaki-twiist-burrito.png",
    null,
    0,
    15,
    null,
    null,
    null
);

# %%
INSERT INTO menus (
	id,
	name,
    price,
    description,
    ingredients,
    nutritionalFacts,
    thumbnailUrl,
    videoUrl,
    likeCount,
    estimatedMinute,
    discount,
    subSection_id,
    restaurant_id
)
VALUES (
	uuid(),
    "Pangoa Burrito",
    '{ "value": 1049, "currency": "CAD" }',
    "Fiery BBQ meets avo, beans, and cheddar in this smoky-sweet wrap.",
    '["Whole Wheat Tortilla", "Brown Rice", "Avocado", "Aged Cheddar", "Cherry Tomatoes", "Black Beans", "Corn", "Cilantro", "Fiery Bbq Sauce"]',
    '[{"name": "Calories", "amount": {"unit": "kcal", "value": 300}}, {"name": "Fat", "amount": {"unit": "g", "value": 0}}, {"name": "Fiber", "amount": {"unit": "g", "value": 0}}, {"name": "Protein", "amount": {"unit": "g", "value": 0}}, {"name": "Carbs", "amount": {"unit": "g", "value": 0}}]',
    "https://d1inbgoespaevw.cloudfront.net/menus/thumbnails/pangoa.png",
    null,
    0,
    15,
    null,
    null,
    null
);

# %%
INSERT INTO menus (
	id,
	name,
    price,
    description,
    ingredients,
    nutritionalFacts,
    thumbnailUrl,
    videoUrl,
    likeCount,
    estimatedMinute,
    discount,
    subSection_id,
    restaurant_id
)
VALUES (
	uuid(),
    "Chocolate Peanut Butter Smoothie",
    '{ "value": 829, "currency": "CAD" }',
    "Creamy banana, cocoa, and peanuts blended to perfection.",
    '["Banana", "Peanuts", "Cocoa Powder", "Frozen Yogurt"]',
    '[{"name": "Calories", "amount": {"unit": "kcal", "value": 650}}, {"name": "Fat", "amount": {"unit": "g", "value": 0}}, {"name": "Fiber", "amount": {"unit": "g", "value": 0}}, {"name": "Protein", "amount": {"unit": "g", "value": 0}}, {"name": "Carbs", "amount": {"unit": "g", "value": 0}}]',
    "https://d1inbgoespaevw.cloudfront.net/menus/thumbnails/chocolate-peanut-butter-smoothie.png,
    null,
    0,
    15,
    null,
    null,
    null
);

# %%
INSERT INTO menus (
	id,
	name,
    price,
    description,
    ingredients,
    nutritionalFacts,
    thumbnailUrl,
    videoUrl,
    likeCount,
    estimatedMinute,
    discount,
    subSection_id,
    restaurant_id
)
VALUES (
	uuid(),
    "Freshii Green Smoothie",
    '{ "value": 829, "currency": "CAD" }',
    "Tropical greens with pineapple, kale, and creamy oat milk.",
    '["Pineapple", "Banana", "Kale", "Avocado", "Oat Milk"]',
    '[{"name": "Calories", "amount": {"unit": "kcal", "value": 350}}, {"name": "Fat", "amount": {"unit": "g", "value": 0}}, {"name": "Fiber", "amount": {"unit": "g", "value": 0}}, {"name": "Protein", "amount": {"unit": "g", "value": 0}}, {"name": "Carbs", "amount": {"unit": "g", "value": 0}}]',
    "https://d1inbgoespaevw.cloudfront.net/menus/thumbnails/freshii-green-smoothie.png,
    null,
    0,
    15,
    null,
    null,
    null
);

# %%
INSERT INTO menus (
	id,
	name,
    price,
    description,
    ingredients,
    nutritionalFacts,
    thumbnailUrl,
    videoUrl,
    likeCount,
    estimatedMinute,
    discount,
    subSection_id,
    restaurant_id
)
VALUES (
	uuid(),
    "Mixed Berrii Smoothie",
    '{ "value": 829, "currency": "CAD" }',
    "A juicy mix of berries and banana with a citrusy twist.",
    '["Blueberry", "Strawberry", "Banana", "Orange Juice"]',
    '[{"name": "Calories", "amount": {"unit": "kcal", "value": 170}}, {"name": "Fat", "amount": {"unit": "g", "value": 0}}, {"name": "Fiber", "amount": {"unit": "g", "value": 0}}, {"name": "Protein", "amount": {"unit": "g", "value": 0}}, {"name": "Carbs", "amount": {"unit": "g", "value": 0}}]',
    "https://d1inbgoespaevw.cloudfront.net/menus/thumbnails/mixed-berrii-smoothie.png,
    null,
    0,
    15,
    null,
    null,
    null
);

# %%
INSERT INTO menus (
	id,
	name,
    price,
    description,
    ingredients,
    nutritionalFacts,
    thumbnailUrl,
    videoUrl,
    likeCount,
    estimatedMinute,
    discount,
    subSection_id,
    restaurant_id
)
VALUES (
	uuid(),
    "Strawberrii Banana Smoothie",
    '{ "value": 829, "currency": "CAD" }',
    "Sweet strawberries and banana blended with frozen yogurt.",
    '["Strawberry", "Banana", "Frozen Yogurt"]',
    '[{"name": "Calories", "amount": {"unit": "kcal", "value": 320}}, {"name": "Fat", "amount": {"unit": "g", "value": 0}}, {"name": "Fiber", "amount": {"unit": "g", "value": 0}}, {"name": "Protein", "amount": {"unit": "g", "value": 0}}, {"name": "Carbs", "amount": {"unit": "g", "value": 0}}]',
    "https://d1inbgoespaevw.cloudfront.net/menus/thumbnails/strawberrii-banana-smoothie.png,
    null,
    0,
    15,
    null,
    null,
    null
);

# %%
INSERT INTO menus (
	id,
	name,
    price,
    description,
    ingredients,
    nutritionalFacts,
    thumbnailUrl,
    videoUrl,
    likeCount,
    estimatedMinute,
    discount,
    subSection_id,
    restaurant_id
)
VALUES (
	uuid(),
    "Tropical Mango Smoothie",
    '{ "value": 829, "currency": "CAD" }',
    "Sunshine in a sip. Mango, banana, pineapple, and a hint of turmeric.",
    '["Mango", "Banana", "Pineapple", "Honey", "Turmeric", "Coconut Milk"]',
    '[{"name": "Calories", "amount": {"unit": "kcal", "value": 440}}, {"name": "Fat", "amount": {"unit": "g", "value": 0}}, {"name": "Fiber", "amount": {"unit": "g", "value": 0}}, {"name": "Protein", "amount": {"unit": "g", "value": 0}}, {"name": "Carbs", "amount": {"unit": "g", "value": 0}}]',
    "https://d1inbgoespaevw.cloudfront.net/menus/thumbnails/tropical-mango-smoothie.png,
    null,
    0,
    15,
    null,
    null,
    null
);
